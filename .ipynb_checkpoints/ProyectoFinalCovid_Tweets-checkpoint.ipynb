# %%
from os import path
from PIL import Image
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv("covid19_tweets1.csv")
df.head()
df.describe()
# Out:
#        user_followers   user_friends  user_favourites
# count    1.791080e+05  179108.000000     1.791080e+05
# mean     1.090555e+05    2121.701566     1.444411e+04
# std      8.414670e+05    9162.553072     4.452270e+04
# min      0.000000e+00       0.000000     0.000000e+00
# 25%      1.720000e+02     148.000000     2.060000e+02
# 50%      9.920000e+02     542.000000     1.791000e+03
# 75%      5.284000e+03    1725.250000     9.388000e+03
# max      4.944256e+07  497363.000000     2.047197e+06

# %% [markdown]
# <h1> Objetivo #1 </h1>

# %% [markdown]
# <h3> Conocer la relación entre el número de tweets por zona geográfica con su situación actual con respecto al COVID-19 </h3>

# %%
plt.figure(figsize=(15,8))
loca = df['user_location'].value_counts().sort_values(ascending=False)
loc= loca.head(10)
loc.plot.bar(color=['orange', 'red', 'green', 'blue'])
plt.title('Paises con mas registro de tweets')
plt.xlabel('Ubicación de los usuarios')
plt.ylabel('Conteo de Tweets')
plt.show()

# %%
def hashtag(x):
  x = str(x)
  x = x.replace('[','')
  x = x.replace(']','')
  x = x.split(',')
  return x
  
df['hashtag'] = df['hashtags'].apply(lambda y : hashtag(y))
df = df.explode('hashtag')
df['hashtag'] = df['hashtag'].astype(str)
df['hashtag'] = df['hashtag'].str.replace("'",'')
df['hashtag'] = df['hashtag'].str.replace('"','')

df['hashtag'] = df['hashtag'].str.replace(" ",'')
df= df[df['hashtag'] != 'nan']

# %%
# Hashtags en todo el mundo
plt.figure(figsize=(15,5))
source = df['hashtag'].value_counts().sort_values(ascending=False)
source = souce.head(6)
source.plot.bar(color=['black', 'red', 'green', 'blue', 'cyan','pink'])
plt.title('10 Hashtags con mayor uso mundial')
plt.xlabel('Hashtag')
plt.ylabel('Conteo')
plt.show()

# %%
df['datedt'] = pd.to_datetime(df['date'])

df['year'] = df['datedt'].dt.year
df['month'] = df['datedt'].dt.month
df['day'] = df['datedt'].dt.day
df['day_name'] = df['datedt'].dt.day_name()
df['hour'] = df['datedt'].dt.hour
df['minute'] = df['datedt'].dt.minute
df['dayofyear'] = df['datedt'].dt.dayofyear
df['date_only'] = df['datedt'].dt.date
#############################
def countplot(feature, title, df, size=1, ordered=True):
    f, ax = plt.subplots(1,1, figsize=(15,4))
    total = float(len(df))
    if ordered:
        g = sns.countplot(df[feature], order = df[feature].value_counts().index[:20], palette='Set3')
    else:
        g = sns.countplot(df[feature], palette='Set3')
    g.set_title("Number and percentage of {}".format(title),weight='bold', size=17)
    if(size > 2):
        plt.xticks(rotation=90, size=10)
    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 
    plt.xlabel(feature, size=12, weight='bold')
    plt.ylabel('Count', size=12, weight='bold')
    plt.show() 
    ################3
countplot("month", "tweets / month", df, size=3, ordered=False)
countplot("hour", "tweets / hour", df,size=4, ordered=False)
# Out:
# C:\Users\leona\Anaconda\envs\SemanaTecAnalitica\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# C:\Users\leona\Anaconda\envs\SemanaTecAnalitica\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df_username_count = df['user_name'].value_counts().reset_index().rename(columns={
    'user_name':'tweet_count','index':'user_name'})

plt.figure(figsize=(15, 17))
sns.barplot(y='user_name',x='tweet_count',data=df_username_count.head(50))
y=df_username_count['tweet_count'].head(50)
for index, value in enumerate(y):
    plt.text(value, index, str(value),fontsize=12)
plt.title('Top50 users by number of tweets',weight='bold', size=15)
plt.ylabel('User_name', size=12, weight='bold')
plt.xlabel('Tweet_count', size=12, weight='bold')
plt.show()

# %%
ds = df['user_location'].value_counts().reset_index()
ds.columns = ['user_location', 'count']
ds = ds[ds['user_location']!='NA']
ds = ds.sort_values(['count'])

fig = px.bar(
    ds.tail(40), 
    x="count", 
    y="user_location", 
    orientation='h', title='Top 40 user locations by number of tweets', 
    width=800, 
    height=800
)

fig.show()
# Out:
# <div>                            <div id="9f1c4f81-ffca-4545-a6a1-117d18dc71cb" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f1c4f81-ffca-4545-a6a1-117d18dc71cb")) {                    Plotly.newPlot(                        "9f1c4f81-ffca-4545-a6a1-117d18dc71cb",                        [{"alignmentgroup": "True", "hovertemplate": "count=%{x}<br>user_location=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [434, 437, 441, 441, 444, 451, 466, 468, 470, 481, 489, 493, 516, 523, 551, 561, 578, 579, 618, 688, 709, 731, 766, 776, 777, 803, 817, 822, 835, 879, 964, 1082, 1103, 1206, 1269, 1354, 1401, 1721, 2455, 3741], "xaxis": "x", "y": ["Bhubaneshwar, India", "Hong Kong", "England, United Kingdom", "San Francisco, CA", "Texas, USA", "Hyderabad, India", "Singapore", "Toronto, Ontario", "Ireland", "Chennai, India", "Boston, MA", "Johannesburg, South Africa", "Earth", "Mumbai", "Switzerland", "Chicago, IL", "Atlanta, GA", "Nigeria", "Nairobi, Kenya", "Global", "California, USA", "Lagos, Nigeria", "South Africa", "Los Angeles, CA", "WORLDWIDE", "UK", "USA", "New Delhi", "Canada", "Worldwide", "Australia", "New York, NY", "London", "United Kingdom", "London, England", "Washington, DC", "Mumbai, India", "New Delhi, India", "United States", "India"], "yaxis": "y"}],                        {"barmode": "relative", "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.444444444444 ...

# %%
ds = df['source'].value_counts().reset_index()
ds.columns = ['source', 'count']
ds = ds.sort_values(['count'])

fig = px.bar(
    ds.tail(40), 
    x="count", 
    y="source", 
    orientation='h', 
    title='Top 40 user sources by number of tweets', 
    width=800, 
    height=800
)

fig.show()
# Out:
# <div>                            <div id="cc34cbc5-b90c-447c-98df-11cdf75599b4" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc34cbc5-b90c-447c-98df-11cdf75599b4")) {                    Plotly.newPlot(                        "cc34cbc5-b90c-447c-98df-11cdf75599b4",                        [{"alignmentgroup": "True", "hovertemplate": "count=%{x}<br>source=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [162, 162, 162, 163, 168, 175, 181, 191, 208, 208, 209, 216, 224, 225, 266, 281, 317, 322, 335, 390, 391, 414, 497, 513, 537, 596, 625, 628, 679, 681, 1545, 1759, 1833, 2728, 4336, 7321, 8543, 35472, 40179, 56891], "xaxis": "x", "y": ["Twitter for Mac", "ContentStudio.io", "SocialFlow", "Oktopost", "Orlo", "Twitter Media Studio - LiveCut", "Tweetbot for i\u039fS", "HN_Comments", "coronaData_Test", "SocialPilot.co", "Fabrik.fm", "The Social Jukebox", "Zoho Social", "Alexander Higgins", "IAMBLOG2TWITTER", "Blood Donors India", "Twitter for Advertisers", "Paper.li", "Cheap Bots, Done Quick!", "Resistbot Open Letters", "Dynamic Signal", "FS Poster", "Sprinklr", "HubSpot", "WordPress.com", "Twitter Media Studio", "COVID19-Updates", "LinkedIn", "GlobalPandemic.NET", "dlvr.it", "IFTTT", "Instagram", "Sprout Social", "Buffer", "Twitter for iPad", "Hootsuite Inc.", "TweetDeck", "Twitter for iPhone", "Twitter for Android", "Twitter Web App"], "yaxis": "y"}],                        {"barmode": "relative", "height": 800, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#4 ...

# %%
df.sort_values(by = 'date', ascending= False)
# Out:
#                          user_name               user_location  \
# 166656                  🍺¯\_(ツ)_/¯                  Boston, MA
# 166657                 Kings Place         Kings Cross, London
# 166658   Keith Bishop 👨‍👨‍👧‍👦 🏳️‍🌈       Newman University, UK
# 166660             Dirk Haussecker                   RNA World
# 166661                     FX_Baba                         NaN
# ...                            ...                         ...
# 17171              Tristyn Russelo             Alberta, Canada
# 17173                  Patty Hayes                 Seattle, WA
# 17174   Dr. Lipi #TrustDrFauci Roy               New York, USA
# 17172                 Clive Gorman  Victoria, British Columbia
# 17175        Jessica Luther Rummel               Denton, Texas
#
#                                          user_description  \
# 166656  Father, husband, musician, dog-lover. All opin...
# 166657  An open, multi-arts venue presenting an advent...
# 166658  Foster Dad, Youth Worker & Senior Lecturer (Ch...
# 166660  RNA(i) Therapeutics Investor-Scientist who lov...
# 166661  FX & Stock Trader - Tweets are not financial a...
# ...                                                   ...
# 17171                                                 NaN
# 17173   Director of Public Health - Seattle & King Cou...
# 17174   @NBCNews @MSNBC @Forbes Medical Contributor | ...
# 17172   Marketing Director @CNEGames for @idlechampion...
# 17175   Mother. Partner. Scholar. Activist. Alchemist....
#
#                user_created  user_followers  user_friends  user_favourites  \
# 166656  2009-04-13 13:14:46              24           197             1409
# 166657  2009-02-26 12:16:47           18930          6213            23986
# 166658  2015-06-20 10:56:58            1244           667             1140
# 166660  2011-11-10 12:00:58            9341           339             7276
# 166661  2017-06-15 18:35:38             277           318              881
# ...                     ...             ...           ...              ...
# 17171   2017-06-14 22:01:54               5            68               57
# 17173   2017-07-07 18:56:50             718           162             2276
# 17174   2009-10-11 18:46:51           12485          4603            38120
# 17172   2011-12-23 02:02:35             597           224            23824
# 17175   2020-07-05 03:28:16             234            28              220
#
#         user_verified                 date  \
# 166656          False  2020-08-30 09:07:39
# 166657          False  2020-08-30 09:07:34
# 166658          False  2020-08-30 09:07:26
# 166660          False  2020-08-30 09:07:25
# 166661          False  2020-08-30 09:07:25
# ...               ...                  ...
# 17171           False  2020-07-24 23:47:13
# 17173           False  2020-07-24 23:47:12
# 17174            True  2020-07-24 23:47:12
# 17172           False  2020-07-24 23:47:12
# 17175           False  2020-07-24 23:47:08
#
#                                                      text     hashtags  \
# 166656  It’s a shame magots can’t celebrate @realDonal...          NaN
# 166657  ⏰ Today @ 11:30!\nTune in for the latest #Bach...     ['Bach']
# 166658  Concerns have been raised that return to unive...  ['COVID19']
# 166660  In Germany, we have ~1-3 deaths/day while dail...          NaN
# 166661  Another great thread about how unreliable and ...          NaN
# ...                                                   ...          ...
# 17171   Apparently, at the Timberlea @saveonfoods stor...          NaN
# 17173   Excellent partnership to prevent #COVID19, tha...  ['COVID19']
# 17174   Always honored to speak w @NicolleDWallace abo...  ['covid19']
# 17172   Don't take your eye off the ball. There are st...  ['COVID19']
# 17175   PROTESTORS NEEDED 6PM-10PM DAILY (NOW). 1450 E...          NaN
#
#                      source  is_retweet
# 166656   Twitter for iPhone       False
# 166657      Twitter Web App       False
# 166658     Twitter for iPad       False
# 166660      Twitter Web App       False
# 166661  Twitter for Android       False
# ...                     ...         ...
# 17171       Twitter Web App       False
# 17173   Twitter for Android       False
# 17174       Twitter Web App       False
# 17172   Twitter for Android       False
# 17175       Twitter Web App       False
#
# [179108 rows x 13 columns]

# %% [markdown]
# Agradecimientos a Notebooks
# Covid_geo_complete_analysis
